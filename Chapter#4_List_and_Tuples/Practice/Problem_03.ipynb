# %% [markdown]
# # ***Practice 3:***
# ## *Checked that Data types in tuple can not be changed.*

# %% [markdown]
# ## ***Solution:***

# %%
a = ( 34, 21, "Hello")
a[2] = "World"
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 a = ( 34, 21, "Hello")
# ----> 2 a[2] = "World"
#       3 print(a)
#
# TypeError: 'tuple' object does not support item assignment
