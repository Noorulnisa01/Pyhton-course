# %% [markdown]
# # ***Practice 1:***
# ## *Write a Program to store seven fruits in a list entered by users.*

# %% [markdown]
# ## ***Solution:***

# %%
Fruits = []

f1 = input("Enter the Fruit name: ")
Fruits.append(f1)
f2 = input("Enter the Fruit name: ")
Fruits.append(f2)
f3 = input("Enter the Fruit name: ")
Fruits.append(f3)
f4 = input("Enter the Fruit name: ")
Fruits.append(f4)
f5 = input("Enter the Fruit name: ")
Fruits.append(f5)
f6 = input("Enter the Fruit name: ")
Fruits.append(f6)
f7 = input("Enter the Fruit name: ")
Fruits.append(f7)

print(Fruits)
# Out:
# ['mango', 'banana\\', 'apple', 'strawbarry', 'grapes', 'watermelon', 'melon']
