# %% [markdown]
# # ***Practice 5:***
# ## *Write a Program to write this in letter format.*
# ```
# letter = '''
# Dear taha, You are selected. thanks!
# '''
# ```

# %% [markdown]
# ## ***Solution:***
#
# #### ***By using escape sequence:***

# %%
letter = '''
Dear taha,\n You are selected.\n thanks!
'''
print(letter)
# Out:
# Dear taha,
#  You are selected.
#  thanks!
